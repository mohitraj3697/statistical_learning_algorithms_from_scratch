# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
class GDRegressor:
    
    def __init__(self,learning_rate=0.01,epochs=225):
        
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X_train,y_train):
       
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])
        
        for i in range(self.epochs):
            # update all the coef and the intercept
            y_hat = np.dot(X_train,self.coef_) + self.intercept_      # y_hat = x_train * coef + intercept
         
            intercept_der = -2 * np.mean(y_train - y_hat)      # slope of loss function with respect to intercept
            self.intercept_ = self.intercept_ - (self.lr * intercept_der)
            
            coef_der = -2 * np.dot((y_train - y_hat),X_train)/X_train.shape[0]      #slope of loss function with respect to coef
            self.coef_ = self.coef_ - (self.lr * coef_der)
        
        print(self.intercept_,self.coef_)
    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
gdr = GDRegressor(epochs=2000,learning_rate=0.01)

# %%
gdr.fit(X_train,y_train)
# Out:
# 151.00637386718694 [ 27.96910357   4.49435115  77.94062458  60.15443867  25.12405028
#   18.63360578 -46.89051311  49.72255623  76.25124492  45.3663814 ]

# %%
y_pred = gdr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.18544037475718567
