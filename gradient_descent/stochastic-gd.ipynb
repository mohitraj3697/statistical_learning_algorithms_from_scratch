# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
class SGDRegressor:
    
    def __init__(self,learning_rate=0.01,epochs=225):
        
        self.coef_ = None
        self.intercept_ = None
        self.lr = learning_rate
        self.epochs = epochs
        
    def fit(self,X_train,y_train):
        
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])      # initialize the coefficients matrix to 1
        
        for i in range(self.epochs):
            for j in range(X_train.shape[0]):    # run no. of rows times
                idx = np.random.randint(0,X_train.shape[0])    # takes a random row index from the training data
                
                y_hat = np.dot(X_train[idx],self.coef_) + self.intercept_
                
                intercept_der = -2 * (y_train[idx] - y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)
                
                coef_der = -2 * np.dot((y_train[idx] - y_hat),X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_der)
        
        print(self.intercept_,self.coef_)
    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
sgd = SGDRegressor(learning_rate=0.01,epochs=56)

# %%
start = time.time()
sgd.fit(X_train,y_train)
print("The time taken is",time.time() - start)
# Out:
# 164.00950593964873 [  54.45570619  -74.50962047  371.52791592  253.20032793    9.95968546
#   -37.42426086 -177.77166022  129.59681317  330.81392208  136.26350022]
# The time taken is 0.0996255874633789

# %%
y_pred = sgd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.41333971254156765
