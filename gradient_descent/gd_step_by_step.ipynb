# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y = make_regression(n_samples=250, n_features=1, n_informative=1, n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
# lets apply OLS
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([2.34758412])

# %%
reg.intercept_
# Out:
# np.float64(0.006046184639290603)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red')

# %%
# lets apply Gradient Descent assuming slope is constant m = 2.35
# and let's assume the starting value for intercept b = 0
y_pred = ((2.35 * X) + 100).reshape(250)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred,color='#00a65a',label='b = 0')
plt.legend()
plt.show()

# %%
m = 2.35
b = 100

loss_slope = -2 * np.sum(y - m*X.ravel() - b)   #equation for slope of loss function with respect to b
loss_slope
# Out:
# np.float64(49996.8713526258)

# %%
# lets take learning rate = 0.1
lr = 0.1

step_size = loss_slope*lr
step_size
# Out:
# np.float64(4999.68713526258)

# %%
# calculating the new intercept
b = b - step_size
b
# Out:
# np.float64(-4899.68713526258)

# %%
y_pred1 = ((2.35 * X) + b).reshape(250)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred1,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# iteration 2
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(-2449846.6962786643)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(-244984.66962786645)

# %%
b = b - step_size
b
# Out:
# np.float64(240084.98249260386)

# %%
y_pred2 = ((2.35 * X) + b).reshape(250)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred2,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='#A3E4D7',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
# iteration 3
loss_slope = -2 * np.sum(y - m*X.ravel() - b)
loss_slope
# Out:
# np.float64(120042488.11765455)

# %%
step_size = loss_slope*lr
step_size
# Out:
# np.float64(12004248.811765455)

# %%
b = b - step_size
b
# Out:
# np.float64(-11764163.829272851)

# %%
y_pred3 = ((2.35 * X) + b).reshape(250)

plt.figure(figsize=(15,15))
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='red',label='OLS')
plt.plot(X,y_pred3,color='#00a65a',label='b = {}'.format(b))
plt.plot(X,y_pred2,color='#A3E4D7',label='b = {}'.format(b))
plt.plot(X,y_pred1,color='#A3E4D7',label='b = {}'.format(b))
plt.plot(X,y_pred,color='#A3E4D7',label='b = 0')
plt.legend()
plt.show()

# %%
b = -100
m = 2.35
lr = 0.01

epochs = 100

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*X.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m * X + b

  plt.plot(X,y_pred)

plt.scatter(X,y)
